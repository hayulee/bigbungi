# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.rc('font', family = 'Malgun Gothic')

# %%
# 보수 구독자수
# 신의 한수, 진성호 방송, 펜앤드마이크TV, 신인균의 국방TV,가로세로 연구소, 고성국tv

age_65_up = 1310 * 0.059 + 1100 * 0.050 + 645 * 0.056 + 786 * 0.051 + 620 * 0.049
age_55_64 = 1310 * 0.134 + 1100 * 0.118 + 645 * 0.130 + 786 * 0.129 + 620 * 0.116
age_45_54 = 1310 * 0.191 + 1100 * 0.196 + 645 * 0.197 + 786 * 0.190 + 620 * 0.171
age_35_44 = 1310 * 0.234 + 1100 * 0.246 + 645 * 0.236 + 786 * 0.239 + 620 * 0.215
age_25_34 = 1310 * 0.201 + 1100 * 0.204 + 645 * 0.202 + 786 * 0.204 + 620 * 0.244
age_18_24 = 1310 * 0.148 + 1100 * 0.151 + 645 * 0.144 + 786 * 0.161 + 620 * 0.171
age_13_17 = 1310 * 0.033 + 1100 * 0.034 + 645 * 0.033 + 786 * 0.027 + 620 * 0.034

# %%
# 보수 구독자수2
# 고성국TV, 황장수의 뉴스브리핑o, 이봉규TV, 뉴스타운TV

a65_up = 540 * 0.060 + 492 * 0.049 + 616 * 0.056 + 492 * 0.057 + 684 * 0.053
a55_64 = 540 * 0.146 + 492 * 0.130 + 616 * 0.127 + 492 * 0.110 + 684 * 0.117
a45_54 = 540 * 0.195 + 492 * 0.211 + 616 * 0.201 + 492 * 0.198 + 684 * 0.192
a35_44 = 540 * 0.246 + 492 * 0.245 + 616 * 0.241 + 492 * 0.248 + 684 * 0.241
a25_34 = 540 * 0.191 + 492 * 0.197 + 616 * 0.206 + 492 * 0.214 + 684 * 0.219
a18_24 = 540 * 0.133 + 492 * 0.138 + 616 * 0.140 + 492 * 0.142 + 684 * 0.147
a13_17 = 540 * 0.030 + 492 * 0.030 + 616 * 0.030 + 492 * 0.032 + 684 * 0.032

# %%
print(age_65_up + a65_up)
print(age_55_64 + a55_64)
print(age_45_54 + a45_54)
print(age_35_44 + a35_44)
print(age_25_34 + a25_34)
print(age_18_24 + a18_24)
print(age_13_17 + a13_17)
# Out:
# 394.17599999999993
# 917.684
# 1409.9070000000002
# 1739.21
# 1511.6680000000001
# 1081.794
# 231.28900000000002

# %%
print(age_13_17 + age_18_24 + age_25_34 + age_35_44 + age_45_54 + age_55_64 
      + age_65_up + a13_17 + a18_24 + a25_34 + a35_44 + a45_54 + a55_64 + a65_up)
# Out:
# 7285.728000000002

# %%
보수 = pd.read_csv('보수_완.csv',sep = ',', engine = 'python')

# %%
s = 보수['구독자']

plt.figure(figsize=(9, 7))
# plt.style.use('ggplot')

explode=(0, 0, 0, 0, 0, 0.2, 0.2)
labels = '13~17세', '18~24세', '25~34세', '35~44세', '45~54세', '55~64세', '60세 이상'
plt.pie(x=s, labels=보수['나이'], autopct='%.1f%%', shadow=True,explode=explode)
plt.legend(bbox_to_anchor=(1.2, 0.7), loc=2, borderaxespad=0.,labels=labels)
plt.title("<보수 유튜버 TOP10의 연령대별 구독자 비율>", fontsize=14)
plt.show()

# %%
s
# Out:
# 0     231289
# 1    1081794
# 2    1511668
# 3    1739210
# 4    1409907
# 5     917684
# 6     394176
# Name: 구독자, dtype: int64

# %%
# 진보 구독자 수
# 사람사는세상노무현재단, TBS 시민의방송, 딴지방송국, newstapa, 서울의 소리 The Voice of Seoul
age_65_up = 1170 * 0.036 + 950 * 0.038 + 802 * 0.044 + 602 * 0.039 + 505 * 0.048
age_55_64 = 1170 * 0.084 + 950 * 0.102 + 802 * 0.109 + 602 * 0.090 + 505 * 0.121
age_45_54 = 1170 * 0.184 + 950 * 0.215 + 802 * 0.186 + 602 * 0.213 + 505 * 0.202
age_35_44 = 1170 * 0.222 + 950 * 0.229 + 802 * 0.206 + 602 * 0.219 + 505 * 0.231
age_25_34 = 1170 * 0.235 + 950 * 0.225 + 802 * 0.246 + 602 * 0.227 + 505 * 0.206
age_18_24 = 1170 * 0.195 + 950 * 0.155 + 802 * 0.171 + 602 * 0.171 + 505 * 0.154
age_13_17 = 1170 * 0.043 + 950 * 0.036 + 802 * 0.037 + 602 * 0.041 + 505 * 0.038

# %%
# 진보 구독자 수2
# 오마이스쿨, MediaVOP, 김용민TV, 시사타파TV, 언론 알아야 바꾼다
b65_up = 445 * 0.033 + 471 * 0.030 + 459 * 0.037 + 436 * 0.045 + 394 * 0.038
b55_64 = 445 * 0.081 + 471 * 0.083 + 459 * 0.100 + 436 * 0.111 + 394 * 0.098
b45_54 = 445 * 0.207 + 471 * 0.191 + 459 * 0.203 + 436 * 0.201 + 394 * 0.209
b35_44 = 445 * 0.194 + 471 * 0.210 + 459 * 0.230 + 436 * 0.234 + 394 * 0.243
b25_34 = 445 * 0.246 + 471 * 0.251 + 459 * 0.235 + 436 * 0.212 + 394 * 0.211
b18_24 = 445 * 0.197 + 471 * 0.191 + 459 * 0.159 + 436 * 0.158 + 394 * 0.165
b13_17 = 445 * 0.042 + 471 * 0.045 + 459 * 0.036 + 436 * 0.039 + 394 * 0.037

# %%
print(age_65_up + b65_up)
print(age_55_64 + b55_64)
print(age_45_54 + b45_54)
print(age_35_44 + b35_44)
print(age_25_34 + b25_34)
print(age_18_24 + b18_24)
print(age_13_17 + b13_17)
# Out:
# 241.61599999999999
# 605.9290000000001
# 1244.173
# 1379.571
# 1437.798
# 1077.759
# 246.047

# %%
진보 = pd.read_csv('진보_완.csv',sep = ',', engine = 'python')

# %%
n = 진보['구독자']
plt.figure(figsize=(9, 7))
# plt.style.use('ggplot')

explode=(0, 0, 0, 0, 0, 0.2, 0.2)
labels = '13~17세', '18~24세', '25~34세', '35~44세', '45~54세', '55~64세', '60세 이상'
plt.pie(x=n, labels=진보['나이'], autopct='%.1f%%', shadow=True, explode=explode)
plt.legend(bbox_to_anchor=(1.2, 0.7), loc=2, borderaxespad=0.,labels=labels)
plt.title("<진보 유튜버 TOP10의 연령대별 구독자 비율>", fontsize=14)
plt.show()

# %%
보수진보 = pd.read_csv('보수_진보_완.csv',sep = ',', engine = 'python')

# %%
보수진보
# Out:
#         나이    비율  진영
# 0   13~17세   3.2  보수
# 1   18~24세  14.8  보수
# 2   25~34세  20.7  보수
# 3   35~44세  23.9  보수
# 4   45~54세  19.4  보수
# 5   55~64세  12.6  보수
# 6   65세 이상   5.4  보수
# 7   13~17세   3.9  진보
# 8   18~24세  17.3  진보
# 9   25~34세  23.1  진보
# 10  35~44세  22.1  진보
# 11  45~54세  20.0  진보
# 12  55~64세   9.7  진보
# 13  65세 이상   3.9  진보

# %%
plt.figure(figsize=(14, 10))

sns.barplot(data = 보수진보, x = '나이', y = '비율', hue = '진영' ,palette='muted')
plt.title("<연령대별 보수-진보 구독자 수 비교>", fontsize=18)
plt.xlabel("연령대", fontsize=16)
plt.ylabel("구독자 비율 (단위_비율)", fontsize=16)
plt.legend(loc="upper right", shadow=True, ncol=1)
plt.show()
